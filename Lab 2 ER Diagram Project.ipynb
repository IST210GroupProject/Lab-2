# %% [markdown]
# # Food Delivery Diagram

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# For our project we picked a food delivery service to present the relationships between entities. For our diagram we have five tables to represent the most significant aspects needed in running a food delivery service. We felt those aspects are orders, food, users, payment history, and delivery. Each of these aspects contain a primary key that we use to help us properly identify their relationships to one another. Aside from these only being used as primary keys they are also forgein keys, which are used as attributes in another entity. Some of these foreign keys include userID, historyID, deliveryID, foodID, and order ID. In a diagram like this there are many one to one relationships, such as user to order, user to deliver, order to payment history. Yet, there are also other relationships such as one to many and many to many. In our diagram we labeled the relationships between each of our entities to clarify the relationships. An example of this is seen in the relationship between orders and food. Each order contains food, as is displayed in the diagram. In the center of the diagram is payment history, which has the most relationships to the other entities because all orders will be added into the payment history which is strongly linked to all the aspects of a users delivery account.
